# %%
import numpy as np
import pandas as pd

# %%
import os

# %%
from skimage.io import imread
from skimage.transform import resize
from PIL import Image

# %%
# Reading the Image data

input_dir= "\\Image classification\\dogs_cats_dataset"

# %%
categories=["cats","dogs"]
for category in categories:
      for file in os.listdir(os.path.join(input_dir,category)):
            img_path=os.path.join(input_dir,category,file)
            print(img_path)
# Out:
# C:\Users\DELL\SANDHYA\PGP_DS_ML\94- Image classification\dogs_cats_dataset\cats\cat.0.jpg
# C:\Users\DELL\SANDHYA\PGP_DS_ML\94- Image classification\dogs_cats_dataset\cats\cat.1.jpg
# C:\Users\DELL\SANDHYA\PGP_DS_ML\94- Image classification\dogs_cats_dataset\cats\cat.10.jpg
# C:\Users\DELL\SANDHYA\PGP_DS_ML\94- Image classification\dogs_cats_dataset\cats\cat.100.jpg
# C:\Users\DELL\SANDHYA\PGP_DS_ML\94- Image classification\dogs_cats_dataset\cats\cat.101.jpg
# C:\Users\DELL\SANDHYA\PGP_DS_ML\94- Image classification\dogs_cats_dataset\cats\cat.102.jpg
# C:\Users\DELL\SANDHYA\PGP_DS_ML\94- Image classification\dogs_cats_dataset\cats\cat.103.jpg
# C:\Users\DELL\SANDHYA\PGP_DS_ML\94- Image classification\dogs_cats_dataset\cats\cat.104.jpg
# C:\Users\DELL\SANDHYA\PGP_DS_ML\94- Image classification\dogs_cats_dataset\cats\cat.105.jpg
# C:\Users\DELL\SANDHYA\PGP_DS_ML\94- Image classification\dogs_cats_dataset\cats\cat.106.jpg
# ...

# %%
img=Image.open("\\Image classification\\dogs_cats_dataset\\dogs\\dog.300.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x364>

# %%
img.size
# Out:
# (450, 364)

# %%
# Converting an image to numpy array
from skimage.io import imread
img=imread(img_path)
print(img)
# Out:
# [[[137 161 187]
#   [130 152 176]
#   [131 149 169]
#   ...
#   [223 235 213]
#   [223 235 213]
#   [223 235 213]]
#
#  [[125 147 171]
#   [119 139 163]
#   [123 140 158]
#   ...
#   [221 233 209]
#   [220 232 208]
#   [220 232 208]]
#
#  [[113 131 155]
#   [111 128 148]
#   [116 132 148]
#   ...
#   [223 236 208]
#   [223 236 208]
#   [223 236 208]]
#
#  ...
#
#  [[153 148 152]
#   [164 158 162]
#   [164 153 159]
#   ...
#   [223 182 188]
#   [223 182 188]
#   [223 182 188]]
#
#  [[153 148 152]
#   [163 157 161]
#   [164 153 159]
#   ...
#   [225 184 190]
#   [225 184 190]
#   [225 184 190]]
#
#  [[153 148 152]
#   [163 157 161]
#   [163 152 158]
#   ...
#   [226 185 191]
#   [226 185 191]
#   [226 185 191]]]

# %%
from skimage.transform import resize
img=resize(img,(15,15))
img
# Out:
# array([[[0.57150566, 0.5697045 , 0.59762949],
#         [0.69355922, 0.70425635, 0.6760147 ],
#         [0.7274073 , 0.74316296, 0.68453454],
#         [0.63550838, 0.64226682, 0.59413882],
#         [0.52762733, 0.51846931, 0.49848052],
#         [0.48419254, 0.46225855, 0.47412898],
#         [0.45714232, 0.43267924, 0.45143806],
#         [0.52317352, 0.50311748, 0.5221659 ],
#         [0.59727609, 0.58744775, 0.57809449],
#         [0.69178214, 0.69730264, 0.65978792],
#         [0.76750452, 0.78340953, 0.72499845],
#         [0.77233852, 0.78728788, 0.72744289],
#         [0.77598811, 0.79214907, 0.73300889],
#         [0.77919238, 0.79202494, 0.7359423 ],
#         [0.77063584, 0.78518105, 0.72901601]],
#
#        [[0.61378367, 0.58526163, 0.58826827],
#         [0.59273656, 0.58828983, 0.59152255],
#         [0.54363933, 0.53342772, 0.51264778],
#         [0.4398219 , 0.41373543, 0.43899198],
#         [0.47503982, 0.43168968, 0.49938868],
# ...

# %%
img=img.flatten()
img
# Out:
# array([0.57150566, 0.5697045 , 0.59762949, 0.69355922, 0.70425635,
#        0.6760147 , 0.7274073 , 0.74316296, 0.68453454, 0.63550838,
#        0.64226682, 0.59413882, 0.52762733, 0.51846931, 0.49848052,
#        0.48419254, 0.46225855, 0.47412898, 0.45714232, 0.43267924,
#        0.45143806, 0.52317352, 0.50311748, 0.5221659 , 0.59727609,
#        0.58744775, 0.57809449, 0.69178214, 0.69730264, 0.65978792,
#        0.76750452, 0.78340953, 0.72499845, 0.77233852, 0.78728788,
#        0.72744289, 0.77598811, 0.79214907, 0.73300889, 0.77919238,
#        0.79202494, 0.7359423 , 0.77063584, 0.78518105, 0.72901601,
#        0.61378367, 0.58526163, 0.58826827, 0.59273656, 0.58828983,
#        0.59152255, 0.54363933, 0.53342772, 0.51264778, 0.4398219 ,
#        0.41373543, 0.43899198, 0.47503982, 0.43168968, 0.49938868,
#        0.54328145, 0.47494809, 0.5444035 , 0.4498075 , 0.40892697,
#        0.4789003 , 0.42640553, 0.39564564, 0.46098995, 0.39239651,
# ...

# %%
img.shape
# Out:
# (675,)

# %%
data = []
labels = []

for category_idx, category in enumerate(categories):
    for file in os.listdir(os.path.join(input_dir, category)):
        img_path = os.path.join(input_dir, category, file)
        img = imread(img_path)  # img is a numpy array
        img= np.resize(img,(200,200,3))
        img = img.astype('float32')
        img /= 255 #scaling
        data.append(img.flatten())
        labels.append(category_idx)

# %%
labels = np.asarray(labels)
data = np.asarray(data)

# %%
data
# Out:
# array([[0.79607844, 0.6431373 , 0.34117648, ..., 0.9764706 , 0.8745098 ,
#         0.58431375],
#        [0.15294118, 0.17254902, 0.15686275, ..., 0.34117648, 0.2627451 ,
#         0.21960784],
#        [0.10196079, 0.11764706, 0.15294118, ..., 0.42745098, 0.40784314,
#         0.38431373],
#        ...,
#        [0.59607846, 0.5254902 , 0.47058824, ..., 0.5568628 , 0.56078434,
#         0.5686275 ],
#        [0.24705882, 0.35686275, 0.15686275, ..., 0.3764706 , 0.45882353,
#         0.23529412],
#        [0.5372549 , 0.6313726 , 0.73333335, ..., 0.627451  , 0.64705884,
#         0.56078434]], dtype=float32)

# %%
labels
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data,labels,test_size=0.2, stratify=labels, random_state = 55)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.54

# %%
# Decision tree Classifier
from sklearn.tree import DecisionTreeClassifier
dtc= DecisionTreeClassifier()
dtc.fit(x_train,y_train)
y_pred=dtc.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.5225

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.5

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.53      0.51       200
#            1       0.50      0.47      0.49       200
#
#     accuracy                           0.50       400
#    macro avg       0.50      0.50      0.50       400
# weighted avg       0.50      0.50      0.50       400
